# %% [markdown]
# <a href="https://colab.research.google.com/github/krimits/Alloys/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas scikit-learn matplotlib

# %%
from keras.datasets import imdb

# Φόρτωση του dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

X_train = vectorize_sequences(X_train)
X_test = vectorize_sequences(X_test)

# %%
X_dev = X_train[:5000]
y_dev = y_train[:5000]
X_train = X_train[5000:]
y_train = y_train[5000:]

# %%
# !pip install --upgrade scikit-learn
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),  # Χρησιμοποίησε το estimator αντί για base_estimator
    n_estimators=50,  # Αριθμός δέντρων
    learning_rate=1
.0  # Ρυθμός μάθησης
)

# %%
adaboost.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_pred = adaboost.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Precision: 0.7397624142256327
# Recall: 0.80208
# F1 Score: 0.7696618431658542

# %%
from IPython import get_ipython
from IPython.display import display
# %%
# !pip install numpy pandas scikit-learn matplotlib
# %%
from keras.datasets import imdb

# Φόρτωση του dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

X_train = vectorize_sequences(X_train)
X_test = vectorize_sequences(X_test)
# %%
X_dev = X_train[:5000]
y_dev = y_train[:5000]
X_train = X_train[5000:]
y_train = y_train[5000:]
# %%
# !pip install --upgrade scikit-learn
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),  # Χρησιμοποίησε το estimator αντί για base_estimator
    n_estimators=50,  # Αριθμός δέντρων
    learning_rate=1.0  # Ρυθμός μάθησης
)
# %%
adaboost.fit(X_train, y_train)
# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_pred = adaboost.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# %%


from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt

# Bringing X_train, y_train, X_dev, y_dev into scope.
# These variables were likely defined in previous cells and are needed here.
# %%
# Φόρτωση του dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

X_train = vectorize_sequences(X_train)
X_test = vectorize_sequences(X_test)
# %%
X_dev = X_train[:5000]
y_dev = y_train[:5000]
X_train = X_train[5000:]
y_train = y_train[5000:]

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),
    n_estimators=30,  # Μειωμένος αριθμός δέντρων για γρηγορότερη εκτέλεση
    learning_rate=1.0
)
train_precision = []
dev_precision = []

for i in range(1, 31):
    adaboost.set_params(n_estimators=i)
    adaboost.fit(X_train, y_train)
    train_precision.append(precision_score(y_train, adaboost.predict(X_train)))
    dev_precision.append(precision_score(y_dev, adaboost.predict(X_dev)))

plt.plot(range(1, 31), train_precision, label="Training Precision")
plt.plot(range(1, 31), dev_precision, label="Development Precision")
plt.xlabel("Number of Estimators")
plt.ylabel("Precision")
plt.legend()
plt.show()
# Out:
# ...
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# Precision: 0.7397624142256327
# Recall: 0.80208
# F1 Score: 0.7696618431658542
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7f01fd2975c6> in <cell line: 90>()
#      90 for i in range(1, 31):
#      91     adaboost.set_params(n_estimators=i)
# ---> 92     adaboost.fit(X_train, y_train)
#      93     train_precision.append(precision_score(y_train, adaboost.predict(X_train)))
#      94     dev_precision.append(precision_score(y_dev, adaboost.predict(X_dev)))
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# ...

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),
    n_estimators=10,  # Μειωμένος αριθμός δέντρων για γρηγορότερη εκτέλεση
    learning_rate=1.0
)

# Λίστες για αποθήκευση των αποτελεσμάτων
train_precision = []
dev_precision = []

# Εκπαίδευση και αξιολόγηση για διαφορετικούς αριθμούς estimators
for i in range(1, 11):  # Μειωμένο εύρος για γρηγορότερη εκτέλεση
    adaboost.set_params(n_estimators=i)
    adaboost.fit(X_train, y_train)
    train_precision.append(precision_score(y_train, adaboost.predict(X_train)))
    dev_precision.append(precision_score(y_dev, adaboost.predict(X_dev)))

# Σχεδίαση των καμπυλών μάθησης
plt.plot(range(1, 11), train_precision, label="Training Precision")
plt.plot(range(1, 11), dev_precision, label="Development Precision")
plt.xlabel("Number of Estimators")
plt.ylabel("Precision")
plt.legend()
plt.show()

# %%
from IPython import get_ipython
from IPython.display import display
# %%
# !pip install numpy pandas scikit-learn matplotlib
# %%
from keras.datasets import imdb

# Φόρτωση του dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

X_train = vectorize_sequences(X_train)
X_test = vectorize_sequences(X_test)
# %%
X_dev = X_train[:5000]
y_dev = y_train[:5000]
X_train = X_train[5000:]
y_train = y_train[5000:]
# %%
# !pip install --upgrade scikit-learn
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),  # Χρησιμοποίησε το estimator αντί για base_estimator
    n_estimators=50,  # Αριθμός δέντρων
    learning_rate=1.0  # Ρυθμός μάθησης
)
# %%
adaboost.fit(X_train, y_train)
# %%
from sklearn.metrics import precision_score, recall_score, f1_score

y_pred = adaboost.predict(X_test)

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# %%


from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt

# Bringing X_train, y_train, X_dev, y_dev into scope.
# These variables were likely defined in previous cells and are needed here.
# %%
# Φόρτωση του dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

X_train = vectorize_sequences(X_train)
X_test = vectorize_sequences(X_test)
# %%
X_dev = X_train[:5000]
y_dev = y_train[:5000]
X_train = X_train[5000:]
y_train = y_train[5000:]

# Create a StandardScaler instance
scaler = StandardScaler(with_mean=False) # StandardScaler with_mean=False

# Fit the scaler on the training data and transform it
X_train = scaler.fit_transform(X_train)

# Transform the development data using the fitted scaler
X_dev = scaler.transform(X_dev)

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),
    n_estimators=30,  # Μειωμένος αριθμός δέντρων για γρηγορότερη εκτέλεση
    learning_rate=1.0
)
train_precision = []
dev_precision = []

for i in range(1, 50):
    adaboost.set_params(n_estimators=i)
    adaboost.fit(X_train, y_train)
    train_precision.append(precision_score(y_train, adaboost.predict(X_train)))
    dev_precision.append(precision_score(y_dev, adaboost.predict(X_dev)))

plt.plot(range(1, 50), train_precision, label="Training Precision")
plt.plot(range(1, 50), dev_precision, label="Development Precision")
plt.xlabel("Number of Estimators")
plt.ylabel("Precision")
plt.legend()
plt.show()
# Out:
# ...
# Precision: 0.7397624142256327
# Recall: 0.80208
# F1 Score: 0.7696618431658542
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-34de0bb96195> in <cell line: 82>()
#      80
#      81 # Create a StandardScaler instance
# ---> 82 scaler = StandardScaler(with_mean=False) # StandardScaler with_mean=False
#      83
#      84 # Fit the scaler on the training data and transform it
#
# NameError: name 'StandardScaler' is not defined

# %%
# !pip install scikit-learn
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler # Import StandardScaler

# Bringing X_train, y_train, X_dev, y_dev into scope.
# These variables were likely defined in previous cells and are needed here.
# %%
# Φόρτωση του dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)
# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1
    return results

X_train = vectorize_sequences(X_train)
X_test = vectorize_sequences(X_test)
# %%
X_dev = X_train[:5000]
y_dev = y_train[:5000]
X_train = X_train[5000:]
y_train = y_train[5000:]

# Create a StandardScaler instance
scaler = StandardScaler(with_mean=False) # StandardScaler with_mean=False

# Fit the scaler on the training data and transform it
X_train = scaler.fit_transform(X_train)

# Transform the development data using the fitted scaler
X_dev = scaler.transform(X_dev)

# Δημιουργία του AdaBoost με decision stumps (δέντρα βάθους 1)
adaboost = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=1),
    n_estimators=30,  # Μειωμένος αριθμός δέντρων για γρηγορότερη εκτέλεση
    learning_rate=1.0
)
train_precision = []
dev_precision = []

for i in range(1, 50):
    adaboost.set_params(n_estimators=i)
    adaboost.fit(X_train, y_train)
    train_precision.append(precision_score(y_train, adaboost.predict(X_train)))
    dev_precision.append(precision_score(y_dev, adaboost.predict(X_dev)))

plt.plot(range(1, 50), train_precision, label="Training Precision")
plt.plot(range(1, 50), dev_precision, label="Development Precision")
plt.xlabel("Number of Estimators")
plt.ylabel("Precision")
plt.legend()
plt.show()
